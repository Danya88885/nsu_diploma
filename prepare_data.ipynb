# %%
import pandas as pd

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_row', None)

# %%
data = pd.read_excel('Таблица_медицина_24.xlsx')

# %%
data = data[data['вид реабилитации'].notna()].copy()

# %%
data#.isna().mean()
# Out:
#                № № по группе реабилитаци  ФИО    вид реабилитации  Возраст  \
# 0   1+RRC:R[36]C            1+RRC:R[36]C  NaN  кардиореабилитация     77.0
# 1              2                       2  NaN  кардиореабилитация     59.0
# 2              3                       3  NaN  кардиореабилитация     84.0
# 3              4                       4  NaN  кардиореабилитация     77.0
# 4              5                       5  NaN  кардиореабилитация     83.0
# 5              6                       6  NaN  кардиореабилитация     59.0
# 6              7                       7  NaN  кардиореабилитация     83.0
# 7              8                       8  NaN  кардиореабилитация     55.0
# 8              9                       9  NaN  кардиореабилитация     60.0
# 9             10                      10  NaN  кардиореабилитация     59.0
# 10            11                      11  NaN  кардиореабилитация     64.0
# ...

# %%
60*100/285
# Out:
# 21.05263157894737
